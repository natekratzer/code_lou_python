# %% [markdown]
# # Code Louisville intro to Pandas

# %% [markdown]
# Pandas is a library that allows us to deal with data in a dataframe format. This is really useful for being able to quickly do data analysis. When importing, it is conventional to import as 'pd' which allows it to later be referenced by typing 'pd' rather than 'pandas'

# %%
import pandas as pd
import os

# %% [markdown]
# I'm using the os to find the current working directory.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bi6fgjk\\Documents\\code_lou_python\\code_lou_python-master'

# %% [markdown]
# I downloaded the data from here: http://greaterlouisvilleproject.org/deep-drivers-of-change/education/ and saved it in my current working directory. Now I'm using Pandas' read_excel command to read it in and save it as a dataframe named edu_df. Then I used the `.head()` method to show the first 6 rows of the dataframe. Pandas also has a `pd.read_csv()` command. You can specify either an absolute file path, or more commonly a relative file path, e.g. `pd.read_csv('data/my_data.csv')`

# %%
edu_df = pd.read_excel('GLP-Codebook.xlsx', 'Edu County', index_col=None, na_values=['NA'])
edu_df.head(n = 6)
# Out:
#            city     county state display_name   FIPS  year  current  baseline  \
# 0    Birmingham  Jefferson    AL          BIR   1073  2005        1         1
# 1  Jacksonville      Duval    FL          JAC  12031  2005        0         1
# 2  Indianapolis     Marion    IN          IND  18097  2005        1         1
# 3    Louisville  Jefferson    KY          LOU  21111  2005        1         1
# 4  Grand Rapids       Kent    MI           GR  26081  2005        1         0
# 5   Kansas City    Jackson    MO           KC  29095  2005        1         1
#
#    under_5_per  five_to_17_per      ...       per_25_64_grad  \
# 0    27.561629       24.424063      ...            14.957714
# 1    18.102449       14.348973      ...            11.562865
# 2    26.649174       19.114679      ...            12.496485
# 3    27.751727       15.684337      ...            15.934613
# 4    19.607122       15.606313      ...            14.104029
# 5    22.583039       19.766415      ...            14.550455
#
#    per_25_34_assoc_plus  per_25_34_bach_plus  per_25_34_grad  \
# 0             36.986318            32.212249        9.140147
# 1             35.051490            27.663203        6.819745
# 2             39.578506            31.695338        6.908782
# 3             41.795956            33.119233        9.321286
# 4             39.952588            31.835959        7.230960
# 5             36.692679            30.443096        7.133329
#
#    bach_plus_per_all  bach_plus_per_white  bach_plus_per_black  \
# 0          24.863193            34.561143            15.130703
# 1          23.493214            27.910648            16.086584
# 2          24.614262            30.634469            15.507141
# 3          25.140119            29.726655            13.401547
# 4          26.851961            30.713895            15.134037
# 5          24.883282            31.588362            14.994156
#
#    bach_plus_per_hispanic  per_high_wage  enrolled_3_4
# 0                9.632123      37.918348          42.8
# 1               23.423926      37.467390          51.2
# 2                8.733152      37.573134          44.5
# 3               24.382419      37.728885          45.3
# 4                6.954463      36.646570          45.9
# 5               11.896291      38.386257          44.2
#
# [6 rows x 23 columns]

# %% [markdown]
# Using `.tail()` shows the last n rows of the dataframe.

# %%
edu_df.tail(n = 6)
# Out:
#           city                          county state display_name    FIPS  \
# 246  St. Louis  St. Louis both city and county    MO          STL  MERGED
# 247  St. Louis  St. Louis both city and county    MO          STL  MERGED
# 248  St. Louis  St. Louis both city and county    MO          STL  MERGED
# 249  St. Louis  St. Louis both city and county    MO          STL  MERGED
# 250  St. Louis  St. Louis both city and county    MO          STL  MERGED
# 251  St. Louis  St. Louis both city and county    MO          STL  MERGED
#
#      year  current  baseline  under_5_per  five_to_17_per      ...       \
# 246  2011        1         0    24.618629       20.954430      ...
# 247  2012        1         0    27.639459       23.246344      ...
# 248  2013        1         0    24.555998       21.949645      ...
# 249  2014        1         0    19.859922       20.170396      ...
# 250  2015        1         0    19.616353       19.718017      ...
# 251  2016        1         0    19.540549       17.330064      ...
#
#      per_25_64_grad  per_25_34_assoc_plus  per_25_34_bach_plus  \
# 246       21.414279             49.728091            41.766240
# 247       21.789192             54.045574            45.147800
# 248       22.162962             53.763148            45.185529
# 249       23.234263             55.968555            48.008356
# 250       23.078656             54.385359            46.610637
# 251             NaN                   NaN                  NaN
#
#      per_25_34_grad  bach_plus_per_all  bach_plus_per_white  \
# 246       14.455011          33.823896            43.948022
# 247       15.853368          35.297808            45.292258
# 248       15.405880          37.007550            47.702164
# 249       17.986457          36.912506            47.231126
# 250       17.854147          36.897841            47.847756
# 251             NaN                NaN                  NaN
#
#      bach_plus_per_black  bach_plus_per_hispanic  per_high_wage  enrolled_3_4
# 246            16.514943               24.942241      44.121865     61.120777
# 247            17.283133               25.286236      44.119923     54.407214
# 248            16.824685               32.867665      45.069622     56.264128
# 249            18.283916               34.872690      47.558253     56.556415
# 250            17.188374               32.551582      45.101145     63.928063
# 251                  NaN                     NaN            NaN           NaN
#
# [6 rows x 23 columns]

# %% [markdown]
# More generally, `.shape` will give the dimensions of the dataframe

# %%
edu_df.shape
# Out:
# (252, 23)

# %% [markdown]
# And passing the pandas dataframe to the list function will produce a list of all the column names.

# %%
list(edu_df)
# Out:
# ['city',
#  'county',
#  'state',
#  'display_name',
#  'FIPS',
#  'year',
#  'current',
#  'baseline',
#  'under_5_per',
#  'five_to_17_per',
#  'child_per',
#  'per_25_64_assoc_plus',
#  'per_25_64_bach_plus',
#  'per_25_64_grad',
#  'per_25_34_assoc_plus',
#  'per_25_34_bach_plus',
#  'per_25_34_grad',
#  'bach_plus_per_all',
#  'bach_plus_per_white',
#  'bach_plus_per_black',
#  'bach_plus_per_hispanic',
#  'per_high_wage',
#  'enrolled_3_4']

# %% [markdown]
# You can use the `.iloc` method to pull data based on its index location.

# %%
edu_df.iloc[3, 8]
# Out:
# 27.7517270253297

# %% [markdown]
# While calling `.iloc[3, 8]` will give you Louisville's child poverty rate in 2005, I don't recommend doing it this way. It's better to select by column name and then filter down to the row(s) you want. It's way too easy to make a mistake with numerical indices. Selecting by column name and filtering data based is covered a bit later in this intro.

# %% [markdown]
# You can pull more than one row and column using the `:` operator. The first index is included, while the second one is excluded, so in the example below asking for rows `1:4` includes row 1 but not row 4

# %%
edu_df.iloc[1:4, 1:9]
# Out:
#       county state display_name   FIPS  year  current  baseline  under_5_per
# 1      Duval    FL          JAC  12031  2005        0         1    18.102449
# 2     Marion    IN          IND  18097  2005        1         1    26.649174
# 3  Jefferson    KY          LOU  21111  2005        1         1    27.751727

# %% [markdown]
# The `:` operator can also be used to select everything up to a certain index - again exclusive of the index you use. Sp :4 gives rows 0 to 3.

# %%
edu_df.iloc[:4, :9]
# Out:
#            city     county state display_name   FIPS  year  current  baseline  \
# 0    Birmingham  Jefferson    AL          BIR   1073  2005        1         1
# 1  Jacksonville      Duval    FL          JAC  12031  2005        0         1
# 2  Indianapolis     Marion    IN          IND  18097  2005        1         1
# 3    Louisville  Jefferson    KY          LOU  21111  2005        1         1
#
#    under_5_per
# 0    27.561629
# 1    18.102449
# 2    26.649174
# 3    27.751727

# %% [markdown]
# Pandas makes it easy to get summary statistics for the whole dataframe. Note though, that Pandas guesses what kind of data it is dealing with. A mean year of 2010.5 doesn't make much sense.

# %%
edu_df.describe()
# Out:
#               year     current    baseline  under_5_per  five_to_17_per  \
# count   252.000000  252.000000  252.000000   252.000000      252.000000
# mean   2010.500000    0.809524    0.714286    26.850341       22.353014
# std       3.458922    0.393458    0.452653     6.223837        6.039708
# min    2005.000000    0.000000    0.000000    12.879569        9.924522
# 25%    2007.750000    1.000000    0.000000    22.547792       18.652877
# 50%    2010.500000    1.000000    1.000000    26.817761       21.711095
# 75%    2013.250000    1.000000    1.000000    30.624183       25.348102
# max    2016.000000    1.000000    1.000000    45.911573       43.958317
#
#         child_per  per_25_64_assoc_plus  per_25_64_bach_plus  per_25_64_grad  \
# count  252.000000            231.000000           231.000000      231.000000
# mean    23.649377             42.192170            34.272072       16.577728
# std      5.808153              5.674435             5.703770        2.788693
# min     10.929946             33.932802            24.393510       11.130579
# 25%     19.921239             37.672312            30.204792       14.526348
# 50%     23.168039             41.253832            33.489888       16.477529
# 75%     27.064674             45.109003            37.518617       18.018369
# max     42.666296             60.687238            52.225352       25.421147
#
#        per_25_34_assoc_plus  per_25_34_bach_plus  per_25_34_grad  \
# count            231.000000           231.000000      231.000000
# mean              43.794477            36.270272       10.686201
# std                6.474984             6.833330        2.804736
# min               30.050042            23.672387        5.602442
# 25%               38.763829            30.567053        8.329107
# 50%               43.474687            36.016016       10.604136
# 75%               48.370058            41.176650       12.829775
# max               59.661496            53.317076       17.986457
#
#        bach_plus_per_all  bach_plus_per_white  bach_plus_per_black  \
# count         231.000000           231.000000           231.000000
# mean           30.168807            37.769598            17.735933
# std             5.257490             7.684775             4.378983
# min            21.448968            24.036965             9.645483
# 25%            26.320250            32.409471            14.798472
# 50%            29.321771            36.455164            16.757468
# 75%            32.619356            40.846901            19.318046
# max            47.782932            59.818743            32.440581
#
#        bach_plus_per_hispanic  per_high_wage  enrolled_3_4
# count              218.000000     231.000000    231.000000
# mean                16.337495      40.864246     46.597050
# std                  7.008783       3.355405      6.971813
# min                  5.323617      34.870455     27.800000
# 25%                 11.301737      38.696424     41.500000
# 50%                 14.591890      40.217741     46.100000
# 75%                 20.033535      42.363616     51.400000
# max                 41.113537      52.519105     63.928063

# %% [markdown]
# The type of a variable can be changed using the `.astype()` method. Here we make year a categorical variable, and it drops out of the `edu_df.describe()` output because it no longer matches the rest of the dataframe.

# %%
edu_df['year'] = edu_df['year'].astype('category')
edu_df.describe()
# Out:
#           current    baseline  under_5_per  five_to_17_per   child_per  \
# count  252.000000  252.000000   252.000000      252.000000  252.000000
# mean     0.809524    0.714286    26.850341       22.353014   23.649377
# std      0.393458    0.452653     6.223837        6.039708    5.808153
# min      0.000000    0.000000    12.879569        9.924522   10.929946
# 25%      1.000000    0.000000    22.547792       18.652877   19.921239
# 50%      1.000000    1.000000    26.817761       21.711095   23.168039
# 75%      1.000000    1.000000    30.624183       25.348102   27.064674
# max      1.000000    1.000000    45.911573       43.958317   42.666296
#
#        per_25_64_assoc_plus  per_25_64_bach_plus  per_25_64_grad  \
# count            231.000000           231.000000      231.000000
# mean              42.192170            34.272072       16.577728
# std                5.674435             5.703770        2.788693
# min               33.932802            24.393510       11.130579
# 25%               37.672312            30.204792       14.526348
# 50%               41.253832            33.489888       16.477529
# 75%               45.109003            37.518617       18.018369
# max               60.687238            52.225352       25.421147
#
#        per_25_34_assoc_plus  per_25_34_bach_plus  per_25_34_grad  \
# count            231.000000           231.000000      231.000000
# mean              43.794477            36.270272       10.686201
# std                6.474984             6.833330        2.804736
# min               30.050042            23.672387        5.602442
# 25%               38.763829            30.567053        8.329107
# 50%               43.474687            36.016016       10.604136
# 75%               48.370058            41.176650       12.829775
# max               59.661496            53.317076       17.986457
#
#        bach_plus_per_all  bach_plus_per_white  bach_plus_per_black  \
# count         231.000000           231.000000           231.000000
# mean           30.168807            37.769598            17.735933
# std             5.257490             7.684775             4.378983
# min            21.448968            24.036965             9.645483
# 25%            26.320250            32.409471            14.798472
# 50%            29.321771            36.455164            16.757468
# 75%            32.619356            40.846901            19.318046
# max            47.782932            59.818743            32.440581
#
#        bach_plus_per_hispanic  per_high_wage  enrolled_3_4
# count              218.000000     231.000000    231.000000
# mean                16.337495      40.864246     46.597050
# std                  7.008783       3.355405      6.971813
# min                  5.323617      34.870455     27.800000
# 25%                 11.301737      38.696424     41.500000
# 50%                 14.591890      40.217741     46.100000
# 75%                 20.033535      42.363616     51.400000
# max                 41.113537      52.519105     63.928063

# %% [markdown]
# But we can select it on its own to describe it.

# %%
edu_df['year'].describe()
# Out:
# count      252
# unique      12
# top       2016
# freq        21
# Name: year, dtype: int64

# %% [markdown]
# The `.describe()` method returns something different depending on the type of data it's passed

# %%
edu_df['child_per'].describe()
# Out:
# count    252.000000
# mean      23.649377
# std        5.808153
# min       10.929946
# 25%       19.921239
# 50%       23.168039
# 75%       27.064674
# max       42.666296
# Name: child_per, dtype: float64

# %% [markdown]
# Pandas also makes it easy to create new variables by performing mathematical operations on already existing variables.

# %%
edu_df['bach_plus_race_gap'] = edu_df['bach_plus_per_white'] - edu_df['bach_plus_per_black']
edu_df.head(n = 6)
# Out:
#            city     county state display_name   FIPS  year  current  baseline  \
# 0    Birmingham  Jefferson    AL          BIR   1073  2005        1         1
# 1  Jacksonville      Duval    FL          JAC  12031  2005        0         1
# 2  Indianapolis     Marion    IN          IND  18097  2005        1         1
# 3    Louisville  Jefferson    KY          LOU  21111  2005        1         1
# 4  Grand Rapids       Kent    MI           GR  26081  2005        1         0
# 5   Kansas City    Jackson    MO           KC  29095  2005        1         1
#
#    under_5_per  five_to_17_per         ...          per_25_34_assoc_plus  \
# 0    27.561629       24.424063         ...                     36.986318
# 1    18.102449       14.348973         ...                     35.051490
# 2    26.649174       19.114679         ...                     39.578506
# 3    27.751727       15.684337         ...                     41.795956
# 4    19.607122       15.606313         ...                     39.952588
# 5    22.583039       19.766415         ...                     36.692679
#
#    per_25_34_bach_plus  per_25_34_grad  bach_plus_per_all  \
# 0            32.212249        9.140147          24.863193
# 1            27.663203        6.819745          23.493214
# 2            31.695338        6.908782          24.614262
# 3            33.119233        9.321286          25.140119
# 4            31.835959        7.230960          26.851961
# 5            30.443096        7.133329          24.883282
#
#    bach_plus_per_white  bach_plus_per_black  bach_plus_per_hispanic  \
# 0            34.561143            15.130703                9.632123
# 1            27.910648            16.086584               23.423926
# 2            30.634469            15.507141                8.733152
# 3            29.726655            13.401547               24.382419
# 4            30.713895            15.134037                6.954463
# 5            31.588362            14.994156               11.896291
#
#    per_high_wage  enrolled_3_4  bach_plus_race_gap
# 0      37.918348          42.8           19.430440
# 1      37.467390          51.2           11.824065
# 2      37.573134          44.5           15.127328
# 3      37.728885          45.3           16.325108
# 4      36.646570          45.9           15.579857
# 5      38.386257          44.2           16.594206
#
# [6 rows x 24 columns]

# %% [markdown]
# Filtering data can be done by using brackets. So suppose we just want Louisville in the year 2005. We can filter to that, and then select the column for under age 5 child poverty. This is a better idea than using `.iloc()` because it won't silently break if the underlying dataframe changes and it's harder to make a mistake with column names and variable values (city == "Louisville) than with index values.

# %%
filtered_df = edu_df[(edu_df.city == "Louisville") & (edu_df.year == 2005)]
filtered_df['under_5_per']
# Out:
# 3    27.751727
# Name: under_5_per, dtype: float64

# %% [markdown]
# We can also combine these operation to avoid creating a new dataframe.

# %%
edu_df[(edu_df.city == "Louisville") & (edu_df.year == 2005)]['under_5_per']
# Out:
# 3    27.751727
# Name: under_5_per, dtype: float64

# %% [markdown]
# ## Joining Data

# %% [markdown]
# Pandas also allows us to merge datasets together relatively painlessly. To start with, we'll need another dataset. Let's read in another sheet from the same excel document.

# %%
jobs_df = pd.read_excel('GLP-Codebook.xlsx', 'Jobs County', index_col=None, na_values=['NA'])
jobs_df.head(n = 6)
# Out:
#          city     county state  FIPS  year  current  baseline  \
# 0  Birmingham  Jefferson    AL  1073  2005        1         1
# 1  Birmingham  Jefferson    AL  1073  2006        1         1
# 2  Birmingham  Jefferson    AL  1073  2007        1         1
# 3  Birmingham  Jefferson    AL  1073  2008        1         1
# 4  Birmingham  Jefferson    AL  1073  2009        1         1
# 5  Birmingham  Jefferson    AL  1073  2010        1         1
#
#    median_earnings  income_inequality  median_household_income  \
# 0          26654.0                NaN                  41821.0
# 1          27026.0                NaN                  41731.0
# 2          29234.0                NaN                  44908.0
# 3          30284.0                NaN                  46269.0
# 4          28820.0                NaN                  43312.0
# 5          26796.0          16.989401                  41740.0
#
#    personal_income_per_cap  unemployment
# 0                  37711.0           4.4
# 1                  40093.0           4.0
# 2                  41109.0           3.9
# 3                  42313.0           5.4
# 4                  40596.0          10.8
# 5                  42248.0          10.3

# %% [markdown]
# Pandas has a `merge()` function that takes the name of the two dataframe, the type of join (left, right, inner, outer) and the names of the columns to join on.

# %%
df = pd.merge(edu_df, jobs_df,  how='outer', left_on=['FIPS','year'], right_on = ['FIPS','year'])
df.head(n = 6)
# Out:
#          city_x   county_x state_x display_name   FIPS  year  current_x  \
# 0    Birmingham  Jefferson      AL          BIR   1073  2005          1
# 1  Jacksonville      Duval      FL          JAC  12031  2005          0
# 2  Indianapolis     Marion      IN          IND  18097  2005          1
# 3    Louisville  Jefferson      KY          LOU  21111  2005          1
# 4  Grand Rapids       Kent      MI           GR  26081  2005          1
# 5   Kansas City    Jackson      MO           KC  29095  2005          1
#
#    baseline_x  under_5_per  five_to_17_per      ...             city_y  \
# 0           1    27.561629       24.424063      ...         Birmingham
# 1           1    18.102449       14.348973      ...       Jacksonville
# 2           1    26.649174       19.114679      ...       Indianapolis
# 3           1    27.751727       15.684337      ...         Louisville
# 4           0    19.607122       15.606313      ...       Grand Rapids
# 5           1    22.583039       19.766415      ...        Kansas City
#
#     county_y  state_y  current_y  baseline_y  median_earnings  \
# 0  Jefferson       AL        1.0         1.0          26654.0
# 1      Duval       FL        0.0         1.0          28666.0
# 2     Marion       IN        1.0         1.0          27555.0
# 3  Jefferson       KY        1.0         1.0          27376.0
# 4       Kent       MI        1.0         0.0          26750.0
# 5    Jackson       MO        1.0         1.0          28503.0
#
#    income_inequality  median_household_income  personal_income_per_cap  \
# 0                NaN                  41821.0                  37711.0
# 1                NaN                  44694.0                  34993.0
# 2                NaN                  42129.0                  34376.0
# 3                NaN                  40973.0                  35987.0
# 4                NaN                  46637.0                  35715.0
# 5                NaN                  43284.0                  31837.0
#
#    unemployment
# 0           4.4
# 1           4.0
# 2           5.6
# 3           5.9
# 4           5.8
# 5           6.4
#
# [6 rows x 34 columns]

# %% [markdown]
# Notice that pandas even renamed duplicated columns. So city was in both datasets and now there is city_x and city_y.

# %%
list(df)
# Out:
# ['city_x',
#  'county_x',
#  'state_x',
#  'display_name',
#  'FIPS',
#  'year',
#  'current_x',
#  'baseline_x',
#  'under_5_per',
#  'five_to_17_per',
#  'child_per',
#  'per_25_64_assoc_plus',
#  'per_25_64_bach_plus',
#  'per_25_64_grad',
#  'per_25_34_assoc_plus',
#  'per_25_34_bach_plus',
#  'per_25_34_grad',
#  'bach_plus_per_all',
#  'bach_plus_per_white',
#  'bach_plus_per_black',
#  'bach_plus_per_hispanic',
#  'per_high_wage',
#  'enrolled_3_4',
#  'bach_plus_race_gap',
#  'city_y',
#  'county_y',
#  'state_y',
#  'current_y',
#  'baseline_y',
#  'median_earnings',
#  'income_inequality',
#  'median_household_income',
#  'personal_income_per_cap',
#  'unemployment']

# %% [markdown]
# That's more columns than we need for this example workbook. Pandas .filter method can be used to select a subset of the columns

# %%
df_sel = df.filter(items = ['city_x', 'year', 'current_x', 'child_per', 'per_25_64_bach_plus', 'per_high_wage'])
df_sel.head(n = 6)
# Out:
#          city_x  year  current_x  child_per  per_25_64_bach_plus  \
# 0    Birmingham  2005          1  25.315549            29.910793
# 1  Jacksonville  2005          0  15.413964            26.062117
# 2  Indianapolis  2005          1  21.445334            27.932248
# 3    Louisville  2005          1  19.195906            30.168911
# 4  Grand Rapids  2005          1  16.747064            30.620225
# 5   Kansas City  2005          1  20.627214            29.683065
#
#    per_high_wage
# 0      37.918348
# 1      37.467390
# 2      37.573134
# 3      37.728885
# 4      36.646570
# 5      38.386257

# %% [markdown]
# In this data, current is an indicator variable that takes 1 if the city is from the current peer city list, and 0 otherwise. There is an older peer city list called baseline. If you work for the city, you should select to keep the `baseline_x` column and then filter to when that variable is equal to 1.

# %%
df_sel = df_sel[(df_sel.current_x == 1)]
df_sel['current_x'].describe()
# Out:
# count    204.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: current_x, dtype: float64

# %% [markdown]
# Some of these names are kind of unwieldy. Let's rename things. And we already showed how to select columsn, but now that `current_x` only takes only the value of 1, we can drop it from the dataframe.

# %%
df_sel = df_sel.rename(columns = {"city_x": "city",
                                  "per_25_64_bach_plus" :"bach", 
                                  "child_per":"child_pov", 
                                  "per_high_wage":"high_wage_jobs"})
df_sel = df_sel.drop('current_x', axis = 1)
list(df_sel)
# Out:
# ['city', 'year', 'child_pov', 'bach', 'high_wage_jobs']

# %% [markdown]
# Pandas easily allows us to look for correlations across all of the data using the .corr() method.

# %%
df_sel.corr()
# Out:
#                 child_pov      bach  high_wage_jobs
# child_pov        1.000000 -0.382622       -0.243805
# bach            -0.382622  1.000000        0.809804
# high_wage_jobs  -0.243805  0.809804        1.000000

# %% [markdown]
# ## Reshaping Data

# %% [markdown]
# A common operation in data science is to transform data from wide to long and vice versa. The data is currently in a long format. It's 204 rows and 5 columns.

# %%
df_sel.shape
# Out:
# (204, 5)

# %%
df_wide = df_sel.pivot(index = 'city', columns = 'year')
df_wide
# Out:
#                child_pov                                              \
# year                2005       2006       2007       2008       2009
# city
# Birmingham     25.315549  20.320927  22.245694  19.170431  23.482029
# Charlotte      15.993880  14.578691  13.138992  13.936343  19.776212
# Cincinnati     19.671406  21.076115  18.856582  20.095994  20.699191
# Columbus       20.142266  21.630252  21.528461  19.593149  25.802145
# Grand Rapids   16.747064  16.929896  18.602906  19.239829  21.006811
# Greensboro     22.110041  21.160935  21.469246  18.762812  22.459487
# Greenville     18.752905  19.712468  16.139407  19.464235  22.449370
# Indianapolis   21.445334  23.184057  22.704913  23.741446  28.478428
# Kansas City    20.627214  24.379493  22.663317  20.821379  23.765657
# Knoxville      19.177288  15.811311  15.287721  18.151228  19.008549
# Louisville     19.195906  22.752912  21.557909  23.133498  22.546513
# Memphis        26.706115  27.671811  30.589489  27.735371  32.033956
# Nashville      23.102665  25.941843  24.676335  27.728797  27.305119
# Oklahoma City  26.731978  25.148822  23.022413  23.690517  25.306982
# Omaha          18.133262  15.578458  17.420406  16.002963  17.700670
# St. Louis      19.578897  20.407225  17.692664  18.774046  21.562939
# Tulsa          22.225332  24.058133  23.281382  20.012369  22.150032
#
#                                                                      ...   \
# year                2010       2011       2012       2013       2014 ...
# Greenville     17.393454  14.364423
# Indianapolis   32.170614  28.464493
# Kansas City    27.073061  24.749306
# Knoxville      20.664445  17.292304
# Louisville     22.432775  20.652497
# Memphis        32.350763  34.527179
# Nashville      27.535363  22.310971
# Oklahoma City  24.711061  25.172032
# Omaha          22.159772  16.243179
# St. Louis      19.628341  17.937648
# Tulsa          24.531516  24.687908

# %% [markdown]
# And we can call down multiple index levels, making it easy to select all our cities for 2016

# %%
df_wide['child_pov'][2016]
# Out:
# city
# Birmingham       21.315103
# Charlotte        18.001947
# Cincinnati       23.519682
# Columbus         24.422872
# Grand Rapids     14.705107
# Greensboro       26.832577
# Greenville       14.364423
# Indianapolis     28.464493
# Kansas City      24.749306
# Knoxville        17.292304
# Louisville       20.652497
# Memphis          34.527179
# Nashville        22.310971
# Oklahoma City    25.172032
# Omaha            16.243179
# St. Louis        17.937648
# Tulsa            24.687908
# Name: 2016, dtype: float64

# %% [markdown]
# You can also sort by using the .sort_values

# %%
df_wide['child_pov'][2016].sort_values
# Out:
# <bound method Series.sort_values of city
# Birmingham       21.315103
# Charlotte        18.001947
# Cincinnati       23.519682
# Columbus         24.422872
# Grand Rapids     14.705107
# Greensboro       26.832577
# Greenville       14.364423
# Indianapolis     28.464493
# Kansas City      24.749306
# Knoxville        17.292304
# Louisville       20.652497
# Memphis          34.527179
# Nashville        22.310971
# Oklahoma City    25.172032
# Omaha            16.243179
# St. Louis        17.937648
# Tulsa            24.687908
# Name: 2016, dtype: float64>

# %% [markdown]
# Except that sorted by city - by default it used the first column. Which is okay if we want them in alphabetical order, but what about order by child poverty?

# %%
df_wide['child_pov'].sort_values(by=[2016])
# Out:
# year                2005       2006       2007       2008       2009  \
# city
# Greenville     18.752905  19.712468  16.139407  19.464235  22.449370
# Grand Rapids   16.747064  16.929896  18.602906  19.239829  21.006811
# Omaha          18.133262  15.578458  17.420406  16.002963  17.700670
# Knoxville      19.177288  15.811311  15.287721  18.151228  19.008549
# St. Louis      19.578897  20.407225  17.692664  18.774046  21.562939
# Charlotte      15.993880  14.578691  13.138992  13.936343  19.776212
# Louisville     19.195906  22.752912  21.557909  23.133498  22.546513
# Birmingham     25.315549  20.320927  22.245694  19.170431  23.482029
# Nashville      23.102665  25.941843  24.676335  27.728797  27.305119
# Cincinnati     19.671406  21.076115  18.856582  20.095994  20.699191
# Columbus       20.142266  21.630252  21.528461  19.593149  25.802145
# Tulsa          22.225332  24.058133  23.281382  20.012369  22.150032
# Kansas City    20.627214  24.379493  22.663317  20.821379  23.765657
# Oklahoma City  26.731978  25.148822  23.022413  23.690517  25.306982
# Greensboro     22.110041  21.160935  21.469246  18.762812  22.459487
# Indianapolis   21.445334  23.184057  22.704913  23.741446  28.478428
# Memphis        26.706115  27.671811  30.589489  27.735371  32.033956
#
# year                2010       2011       2012       2013       2014  \
# city
# Greenville     21.304798  25.776793  24.406126  26.838484  22.050896
# Grand Rapids   23.955846  19.906764  24.451626  18.200520  20.772052
# Omaha          21.855716  20.427377  20.951350  20.495950  18.929419
